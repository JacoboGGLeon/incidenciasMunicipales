# %%
import pandas as pd
import numpy as np

# %%
df_path = "Incidencia_municipal_2011_-_2017_clean"
df = pd.read_csv(df_path)
df.head()
# Out:
#     AÑO  INEGI         ENTIDAD       MUNICIPIO              MODALIDAD  \
# 0  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 1  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 2  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 3  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 4  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
#
#                       TIPO                  SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0       ABUSO DE CONFIANZA       ABUSO DE CONFIANZA     45       43     34
# 1  DAÑO EN PROPIEDAD AJENA  DAÑO EN PROPIEDAD AJENA    164      177    160
# 2                EXTORSION                EXTORSION     10       24      9
# 3                   FRAUDE                   FRAUDE     54       29     37
# 4                  DESPOJO            CON VIOLENCIA      0        0      0
#
#        ...        SEPTIEMBRE  OCTUBRE  NOVIEMBRE  DICIEMBRE  CVE_MUN  CVE_ENT  \
# ...

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#     AÑO  INEGI         ENTIDAD       MUNICIPIO              MODALIDAD  \
# 0  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 1  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 2  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 3  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
# 4  2011   1001  AGUASCALIENTES  AGUASCALIENTES  DELITOS PATRIMONIALES
#
#                       TIPO                  SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0       ABUSO DE CONFIANZA       ABUSO DE CONFIANZA     45       43     34
# 1  DAÑO EN PROPIEDAD AJENA  DAÑO EN PROPIEDAD AJENA    164      177    160
# 2                EXTORSION                EXTORSION     10       24      9
# 3                   FRAUDE                   FRAUDE     54       29     37
# 4                  DESPOJO            CON VIOLENCIA      0        0      0
#
#        ...        SEPTIEMBRE  OCTUBRE  NOVIEMBRE  DICIEMBRE  CVE_MUN  CVE_ENT  \
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851796 entries, 0 to 851795
# Data columns (total 25 columns):
# AÑO              851796 non-null int64
# INEGI            851796 non-null int64
# ENTIDAD          851796 non-null object
# MUNICIPIO        851796 non-null object
# MODALIDAD        851796 non-null object
# TIPO             851796 non-null object
# SUBTIPO          851796 non-null object
# ENERO            851796 non-null int64
# FEBRERO          851796 non-null int64
# MARZO            851796 non-null int64
# ABRIL            851796 non-null int64
# MAYO             851796 non-null int64
# JUNIO            851796 non-null int64
# JULIO            851796 non-null int64
# AGOSTO           851796 non-null int64
# SEPTIEMBRE       851796 non-null int64
# OCTUBRE          851796 non-null int64
# NOVIEMBRE        851796 non-null int64
# DICIEMBRE        851796 non-null int64
# CVE_MUN          851796 non-null int64
# CVE_ENT          851796 non-null int64
# ...

# %%
df_copy.isnull().any().any()
# Out:
# False

# %%
df_copy.columns
# Out:
# Index(['AÑO', 'INEGI', 'ENTIDAD', 'MUNICIPIO', 'MODALIDAD', 'TIPO', 'SUBTIPO',
#        'ENERO', 'FEBRERO', 'MARZO', 'ABRIL', 'MAYO', 'JUNIO', 'JULIO',
#        'AGOSTO', 'SEPTIEMBRE', 'OCTUBRE', 'NOVIEMBRE', 'DICIEMBRE', 'CVE_MUN',
#        'CVE_ENT', 'CVE_MOD', 'CVE_TIPO', 'CVE_SUBTIPO', 'TOTAL_DELITOS'],
#       dtype='object')

# %%
list_numeric_columns = ['CVE_ENT', 'CVE_MUN', 'CVE_MOD', 'CVE_TIPO', 'CVE_SUBTIPO', 'ENERO', 
                        'FEBRERO', 'MARZO', 'ABRIL', 'MAYO', 'JUNIO', 'JULIO', 'AGOSTO', 'SEPTIEMBRE', 
                        'OCTUBRE', 'NOVIEMBRE', 'DICIEMBRE', 'TOTAL_DELITOS']

df_copy[list_numeric_columns].head()
# Out:
#    CVE_ENT  CVE_MUN  CVE_MOD  CVE_TIPO  CVE_SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0        1        1        0         0            0     45       43     34
# 1        1        1        0         1            1    164      177    160
# 2        1        1        0         2            2     10       24      9
# 3        1        1        0         3            3     54       29     37
# 4        1        1        0         4            4      0        0      0
#
#    ABRIL  MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  \
# 0     22    36     43     37      38          37       35         32
# 1    179   167    149    150     144         171      144        134
# 2      7     8      9      9       1           7        6          4
# 3     37    53     37     44      36          27       20         38
# 4      0     0      0      0       0           0        0          0
#
#    DICIEMBRE  TOTAL_DELITOS
# 0         28            385
# 1        173           1748
# ...

# %%
print('Shape 2011: ', df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].shape)
print('Shape 2012: ', df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].shape)
print('Shape 2013: ', df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].shape)
print('Shape 2014: ', df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].shape)
print('Shape 2015: ', df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].shape)
print('Shape 2016: ', df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].shape)
print('Shape 2017: ', df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].shape)
# Out:
# Shape 2011:  (91080, 18)
# Shape 2012:  (91080, 18)
# Shape 2013:  (91080, 18)
# Shape 2014:  (91080, 18)
# Shape 2015:  (91080, 18)
# Shape 2016:  (91080, 18)
# Shape 2017:  (91080, 18)

# %%
df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].head()
# Out:
#    CVE_ENT  CVE_MUN  CVE_MOD  CVE_TIPO  CVE_SUBTIPO  ENERO  FEBRERO  MARZO  \
# 0        1        1        0         0            0     45       43     34
# 1        1        1        0         1            1    164      177    160
# 2        1        1        0         2            2     10       24      9
# 3        1        1        0         3            3     54       29     37
# 4        1        1        0         4            4      0        0      0
#
#    ABRIL  MAYO  JUNIO  JULIO  AGOSTO  SEPTIEMBRE  OCTUBRE  NOVIEMBRE  \
# 0     22    36     43     37      38          37       35         32
# 1    179   167    149    150     144         171      144        134
# 2      7     8      9      9       1           7        6          4
# 3     37    53     37     44      36          27       20         38
# 4      0     0      0      0       0           0        0          0
#
#    DICIEMBRE  TOTAL_DELITOS
# 0         28            385
# 1        173           1748
# ...

# %%
path = 'incidenciaMunicipal_2011_clean_cat.csv'
df_copy[list_numeric_columns][(df_copy.AÑO == 2011)].to_csv(path_or_buf=path, encoding='UTF-8', index=False)

# %%
path = 'incidenciaMunicipal_2012_clean_cat.csv'
df_copy[list_numeric_columns][(df_copy.AÑO == 2012)].to_csv(path_or_buf=path, encoding='UTF-8', index=False)

# %%
path = 'incidenciaMunicipal_2013_clean_cat.csv'
df_copy[list_numeric_columns][(df_copy.AÑO == 2013)].to_csv(path_or_buf=path, encoding='UTF-8', index=False)

# %%
path = 'incidenciaMunicipal_2014_clean_cat.csv'
df_copy[list_numeric_columns][(df_copy.AÑO == 2014)].to_csv(path_or_buf=path, encoding='UTF-8', index=False)

# %%
path = 'incidenciaMunicipal_2015_clean_cat.csv'
df_copy[list_numeric_columns][(df_copy.AÑO == 2015)].to_csv(path_or_buf=path, encoding='UTF-8', index=False)

# %%
path = 'incidenciaMunicipal_2016_clean_cat.csv'
df_copy[list_numeric_columns][(df_copy.AÑO == 2016)].to_csv(path_or_buf=path, encoding='UTF-8', index=False)

# %%
path = 'incidenciaMunicipal_2017_clean_cat.csv'
df_copy[list_numeric_columns][(df_copy.AÑO == 2017)].to_csv(path_or_buf=path, encoding='UTF-8', index=False)
